# %% [markdown]
# <a href="https://colab.research.google.com/github/merchik1/lab/blob/main/untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 15.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np 
import CoolProp.CoolProp as ct
import matplotlib.pyplot as plt
t=np.linspace(73.15,393.15,100)
Fluid_name='CH4'
#10-100 gradus
p=101300
d=ct.PropsSI('D','P',p,'T',t,Fluid_name)
plt.plot(t,d,'r')
plt.grid
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
